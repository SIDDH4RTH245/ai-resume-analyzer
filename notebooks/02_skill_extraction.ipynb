# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/ai-resume-analyzer/blob/main/notebooks/02_skill_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
skills = [
    "python",
    "machine learning",
    "deep learning",
    "tensorflow",
    "pandas",
    "sql",
    "nlp",
    "streamlit"
]

# %%
resume_text = text.lower()

found_skills = []

for skill in skills:
    if skill in resume_text:
        found_skills.append(skill)

print(found_skills)
# Out:
# ['python', 'pandas', 'sql']
