# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/ai-resume-analyzer/blob/main/notebooks/01_resume_parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from pypdf import PdfReader

reader = PdfReader("/content/SIDDHARTH MISTRY_resume.pdf")

text = ""

for page in reader.pages:
    text += page.extract_text()

print(text[:1000])
# Out:
# SIDDHARTH MISTRY
# DATA SCIENCE
# Surat | +91 7096315374 | siddharthgmistry24@gmail.com
# LinkedIn: www.linkedin.com/in/siddharth245
# GitHub:  github.com/SIDDH4RTH245
#
# SUMMARY
# Data Science enthusiast with hands-on experience in building and optimizing AI-driven applications. Skilled in Python,
# FastAPI, and data preprocessing, with a strong ability to transform unstructured data into meaningful insights.
# Passionate about developing efficient data solutions and continuously learning new technologies.
#
# PROFESSIONAL EXPERIENCE
# Data Science
# We3Vision | 6 Months
#  Performed data cleaning and preprocessing to improve data quality and consistency for chatbot responses.
#  Converted unstructured AI responses into structured JSON format and implemented table-based data
# visualization.
#  Developed backend APIs using FastAPI and implemented efficient logic for handling user queries.
# ...
