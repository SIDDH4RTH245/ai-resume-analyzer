# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/ai-resume-analyzer/blob/main/notebooks/03_matching_engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
job_description = """
Looking for Python developer with NLP, SQL, TensorFlow, Streamlit experience
"""

# %%
job_text = job_description.lower()

required = []

for skill in skills:
    if skill in job_text:
        required.append(skill)

print(required)
# Out:
# ['python', 'tensorflow', 'sql', 'nlp', 'streamlit']
